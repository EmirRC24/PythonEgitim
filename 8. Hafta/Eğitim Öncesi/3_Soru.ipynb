# %% [markdown]
# # Problem 3
#
# Çeşitli metin dosyalarından karakterleri ayıklamak ve bir listeye koymak için bir Python programı yazın. ```test.txt``` ve ```demo.txt``` dosyalarından faydalanabilirsiniz.

# %%
#Sorunun Çözmünü Buraya Gerçekleştirebilirsiniz
def read_characters_from_files(file_paths):
    characters_list = []
    for file_path in file_paths:
        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:
                    for character in line:
                        characters_list.append(character)
        except FileNotFoundError:
            print(f"The file {file_path} does not exist.")
    return characters_list

file_paths = ['test.txt', 'demo.txt']

characters_list = read_characters_from_files(file_paths)

print("Characters in the files:")
print(characters_list)
# Out:
# Characters in the files:
# ['a', '\n', 'D', 'e', 'n', 'e', 'm', 'e', '\n', 'D', 'e', 'n', 'e', 'm', 'e', '\n', 's', '\n', 'a', '\n', '5', 'a', 's', 'd', 's', 'd', 'f', 's', '\n', 'd', 'f', 'f', 'h', 'g', 'm', 'h', '\n', 'd', 'f', 'b', 'g', 'f', 'n', 'g', '\n']
