# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
import os

def vki_hesapla(boy, kilo):
    return kilo / (boy ** 2)

def vki_siniflandir(vki):
    if vki < 18.5:
        return "Zayıf"
    elif 18.5 <= vki < 24.9:
        return "Normal kilolu"
    elif 25 <= vki < 29.9:
        return "Fazla kilolu"
    elif 30 <= vki < 39.9:
        return "Obez"
    else:
        return "İleri derecede obez (morbid obez)"

def veri_giris_platformu():
    dosya_adi = "vki_verileri.txt"

    try:
        giris_sayisi = int(input("Kaç kişinin bilgilerini gireceksiniz? "))
    except ValueError:
        print("Lütfen geçerli bir sayı girin.")
        return

    with open(dosya_adi, "w") as dosya:
        for i in range(giris_sayisi):
            print(f"\n{i+1}. kişi için bilgileri girin:")
            
            isim_soyisim = input("İsim Soyisim: ")
            try:
                yas = int(input("Yaş: "))
                boy = float(input("Boy (metre cinsinden, örn: 1.75): "))
                kilo = float(input("Kilo: "))
            except ValueError:
                print("Lütfen geçerli bir değer girin.")
                continue

            vki = vki_hesapla(boy, kilo)
            sinif = vki_siniflandir(vki)

            dosya.write(f"İsim Soyisim: {isim_soyisim}, Yaş: {yas}, Boy: {boy}, Kilo: {kilo}, VKİ: {vki:.2f}, Sınıf: {sinif}\n")

            print(f"{isim_soyisim} için VKİ: {vki:.2f}, Sınıf: {sinif}")

    print("\nTüm veriler kaydedildi.")

veri_giris_platformu()
# Out:
# 1. kişi için bilgileri girin:
# Mustafa Aktaş için VKİ: 25.31, Sınıf: Fazla kilolu
#
# 2. kişi için bilgileri girin:
# Lütfen geçerli bir değer girin.
#
# Tüm veriler kaydedildi.

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
# 2.Problemin Çözümünü Buraya Yazınız
import datetime

menu = {
    "Çilek": 2.0,
    "Muz": 1.5,
    "Elma": 1.0,
    "Ispanak": 1.2,
    "Yoğurt": 1.5,
    "Süt": 1.0,
    "Bal": 0.5,
    "Yulaf": 0.8
}

def menu_goruntule():
    print("Smoothie Menüsü:")
    for urun, fiyat in menu.items():
        print(f"{urun}: {fiyat:.2f} TL")

def satin_alma():
    secimler = []
    toplam_fiyat = 0.0
    
    while True:
        menu_goruntule()
        urun = input("Eklemek istediğiniz ürünü seçin (çıkmak için 'q' tuşlayın): ")
        if urun.lower() == 'q':
            break
        elif urun in menu:
            secimler.append(urun)
            toplam_fiyat += menu[urun]
            print(f"{urun} eklendi. Güncel toplam: {toplam_fiyat:.2f} TL")
        else:
            print("Menüde böyle bir ürün yok. Lütfen tekrar deneyin.")
    
    if secimler:
        tarih = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        kayit = f"Tarih: {tarih}, Ürünler: {', '.join(secimler)}, Toplam Fiyat: {toplam_fiyat:.2f} TL\n"
        with open("satin_almalar.txt", "a") as dosya:
            dosya.write(kayit)
        print("Satın alma işleminiz kaydedildi.")
    else:
        print("Hiçbir ürün seçilmedi.")

def ana_menu():
    while True:
        print("\nYetBar - Smoothie Bank")
        print("1. Menüyü Görüntüle")
        print("2. Satın Alma")
        print("3. Çıkış")
        
        secim = input("Bir seçenek seçin: ")
        
        if secim == '1':
            menu_goruntule()
        elif secim == '2':
            satin_alma()
        elif secim == '3':
            print("Çıkış yapılıyor...")
            break
        else:
            print("Geçersiz seçenek. Lütfen tekrar deneyin.")

ana_menu()
# Out:
# YetBar - Smoothie Bank
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Smoothie Menüsü:
# Çilek: 2.00 TL
# Muz: 1.50 TL
# Elma: 1.00 TL
# Ispanak: 1.20 TL
# Yoğurt: 1.50 TL
# Süt: 1.00 TL
# Bal: 0.50 TL
# Yulaf: 0.80 TL
#
# YetBar - Smoothie Bank
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Smoothie Menüsü:
# Çilek: 2.00 TL
# Muz: 1.50 TL
# Elma: 1.00 TL
# Ispanak: 1.20 TL
# Yoğurt: 1.50 TL
# Süt: 1.00 TL
# Bal: 0.50 TL
# Yulaf: 0.80 TL
# Çilek eklendi. Güncel toplam: 2.00 TL
# Smoothie Menüsü:
# Çilek: 2.00 TL
# Muz: 1.50 TL
# Elma: 1.00 TL
# Ispanak: 1.20 TL
# Yoğurt: 1.50 TL
# Süt: 1.00 TL
# Bal: 0.50 TL
# Yulaf: 0.80 TL
# Satın alma işleminiz kaydedildi.
#
# YetBar - Smoothie Bank
# 1. Menüyü Görüntüle
# 2. Satın Alma
# 3. Çıkış
# Çıkış yapılıyor...
